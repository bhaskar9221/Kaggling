# %% [markdown]
# # XGB One-Versus-Rest — Improved
# Key improvements over v001:
# - **Original data used for training** (was loaded but never trained on)
# - **All FE applied to `orig`** (digit, threshold, logit features)
# - **StratifiedKFold** instead of plain KFold
# - **Ratio / interaction features** between main numeric drivers
# - **3-way categorical combos** enabled
# - **500 Optuna trials** (was 200) for class-weight post-processing
# - XGB: added `gamma`, lower `learning_rate` for precision

# %%
NAME = '002'

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import TargetEncoder, RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.utils.class_weight import compute_sample_weight
import xgboost as xgb
import seaborn as sns

# %%
# %load_ext cudf.pandas
import pandas as pd
import numpy as np, pandas as pd, gc
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 200)

# %%
train_file = '/kaggle/input/competitions/playground-series-s6e4/train.csv'
test_file  = '/kaggle/input/competitions/playground-series-s6e4/test.csv'
original_file = '/kaggle/input/datasets/miadul/irrigation-water-requirement-prediction-dataset/irrigation_prediction.csv'

train = pd.read_csv(train_file)
test  = pd.read_csv(test_file)
orig  = pd.read_csv(original_file)

train_ids = train['id'].copy()
test_ids  = test['id'].copy()  # for submission

print(f"train: {train.shape}, test: {test.shape}, orig: {orig.shape}")
# Out:
# train: (630000, 21), test: (270000, 20), orig: (10000, 20)

# %%
train['Irrigation_Need'] = train['Irrigation_Need'].map(_classes := {'Low': 0, 'Medium': 1, 'High': 2})
orig['Irrigation_Need']  = orig['Irrigation_Need'].map(_classes)

# %%
TARGET = 'Irrigation_Need'
NUMS = list(train.drop(['id', TARGET], axis=1)._get_numeric_data().columns)
CATS = [c for c in train.drop(['id', TARGET], axis=1).columns if c not in NUMS]

# simple check: id + target = 2
assert len(NUMS) + len(CATS) + 2 == train.shape[1]

print(f"Categorical columns ({len(CATS)}): {CATS}")
print(f"Numerical  columns  ({len(NUMS)}): {NUMS}")
# Out:
# Categorical columns (8): ['Soil_Type', 'Crop_Type', 'Crop_Growth_Stage', 'Season', 'Irrigation_Type', 'Water_Source', 'Mulching_Used', 'Region']
# Numerical  columns  (11): ['Soil_pH', 'Soil_Moisture', 'Organic_Carbon', 'Electrical_Conductivity', 'Temperature_C', 'Humidity', 'Rainfall_mm', 'Sunlight_Hours', 'Wind_Speed_kmh', 'Field_Area_hectare', 'Previous_Irrigation_mm']

# %% [markdown]
# # Feature Engineering

# %%
NEW_NUMS   = []
NEW_CATS   = []
NUM_AS_CAT = []
TO_REMOVE  = []
NON_TE_CATS = []

# %%
_to_combo = CATS

for i, c1 in enumerate(_to_combo[:-1]):
    for j, c2 in enumerate(_to_combo[i + 1:]):
        _new_col = f'COMBO_{c1}_{c2}'
        for df in [train, test, orig]:
            df[_new_col] = df[c1].astype('str') + '_' + df[c2].astype('str')
        NEW_CATS.append(_new_col)

        # 3-way combos (enabled — adds useful signal)
        for k, c3 in enumerate(_to_combo[i+j+2:]):
            _new_col3 = f'COMBO_{c1}_{c2}_{c3}'
            for df in [train, test, orig]:
                df[_new_col3] = df[c1].astype('str') + '_' + df[c2].astype('str') + '_' + df[c3].astype('str')
            NEW_CATS.append(_new_col3)

print(f"Total NEW_CATS so far (combos): {len(NEW_CATS)}")
# Out:
# Total NEW_CATS so far (combos): 84

# %%
# Compute frequencies from ALL data (train + orig + test)
for cat in CATS + NEW_CATS:
    freq = pd.concat([train[cat], orig[cat], test[cat]]).value_counts(normalize=True)
    for df in [train, test, orig]:
        df[f'FREQ_{cat}'] = df[cat].map(freq).fillna(0).astype('float32')
    NEW_NUMS.append(f'FREQ_{cat}')

print(f"Freq features added: {len([c for c in NEW_NUMS if c.startswith('FREQ_')])}")
# Out:
# Freq features added: 92

# %%
# numerical as categorical
for col in NUMS:
    _new_col = f'CAT_{col}'
    NUM_AS_CAT.append(_new_col)
    for df in [train, test, orig]:
        df[_new_col] = df[col].astype(str).astype('category')

# %%
# adapted from https://www.kaggle.com/code/yunsuxiaozi/pss6e4-xgb-cv-0-979805
# FIX: now applied to orig as well so orig can be used in training

M = train[NUMS].max()
DIGIT_FEATURES = []

for c in NUMS:
    for df in [train, test, orig]:   # <-- orig added
        for k in range(-4, 4):
            df[f"{c}_digit{k}"] = (df[c] // (10**k) % 10).astype('int8')
            DIGIT_FEATURES += [f"{c}_digit{k}"]

    # Rounding (use max from train for consistency)
    for df in [train, test, orig]:
        if M[c] < 10:
            df[c] = df[c].round(3)
        elif M[c] < 100:
            df[c] = df[c].round(2)
        else:
            df[c] = df[c].round(1)

DIGIT_FEATURES = list(set(DIGIT_FEATURES))

DROP = [c for c in test.columns if test[c].nunique() == 1]
print(f"DROP: {DROP}")

train.drop(DROP, axis=1, inplace=True)
test.drop(DROP,  axis=1, inplace=True)
orig.drop([c for c in DROP if c in orig.columns], axis=1, inplace=True)

DIGIT_FEATURES = list(set(DIGIT_FEATURES) - set(DROP))
NEW_CATS += DIGIT_FEATURES
# Out:
# DROP: ['Soil_pH_digit1', 'Soil_pH_digit2', 'Soil_pH_digit3', 'Soil_Moisture_digit2', 'Soil_Moisture_digit3', 'Organic_Carbon_digit1', 'Organic_Carbon_digit2', 'Organic_Carbon_digit3', 'Electrical_Conductivity_digit1', 'Electrical_Conductivity_digit2', 'Electrical_Conductivity_digit3', 'Temperature_C_digit2', 'Temperature_C_digit3', 'Humidity_digit2', 'Humidity_digit3', 'Sunlight_Hours_digit2', 'Sunlight_Hours_digit3', 'Wind_Speed_kmh_digit2', 'Wind_Speed_kmh_digit3', 'Field_Area_hectare_digit2', 'Field_Area_hectare_digit3', 'Previous_Irrigation_mm_digit3']

# %% [markdown]
# see https://www.kaggle.com/code/cdeotte/original-data-exact-formula for exact formula for `orig`

# %%
# FIX: threshold features now applied to orig
for df in [train, test, orig]:   # <-- orig added
    df["soil_lt_25"]   = (df["Soil_Moisture"]   < 25).astype(int)
    df["temp_gt_30"]   = (df["Temperature_C"]   > 30).astype(int)
    df["rain_lt_300"]  = (df["Rainfall_mm"]      < 300).astype(int)
    df["wind_gt_10"]   = (df["Wind_Speed_kmh"]   > 10).astype(int)

TRES_CATS = ['soil_lt_25', 'temp_gt_30', 'rain_lt_300', 'wind_gt_10']
NEW_CATS += TRES_CATS

# %%
# FIX: logit features now applied to orig as well
for df_ in [train, test, orig]:   # <-- orig added
    df = pd.get_dummies(
        df_[NUMS + CATS + TRES_CATS],
        columns=CATS,
        drop_first=False
    )
    df_['logit(P(y=Low))']    = ( 16.3173 + (-11.0237 * df["soil_lt_25"]) + (-5.8559 * df["temp_gt_30"])
        + (-10.8500 * df["rain_lt_300"]) + (-5.8284 * df["wind_gt_10"])
        + (-5.4155 * df["Crop_Growth_Stage_Flowering"]) + (5.5073 * df["Crop_Growth_Stage_Harvest"])
        + (5.2299  * df["Crop_Growth_Stage_Sowing"])   + (-5.4617 * df["Crop_Growth_Stage_Vegetative"])
        + (-3.0014 * df["Mulching_Used_No"])            + (2.8613 * df["Mulching_Used_Yes"]))
    df_['logit(P(y=Medium))'] = ( 4.6524 + (0.3290 * df["soil_lt_25"]) + (-0.0204 * df["temp_gt_30"])
        + (0.1542 * df["rain_lt_300"]) + (0.0841 * df["wind_gt_10"])
        + (0.3586 * df["Crop_Growth_Stage_Flowering"]) + (-0.1348 * df["Crop_Growth_Stage_Harvest"])
        + (-0.3547 * df["Crop_Growth_Stage_Sowing"])   + (0.3334  * df["Crop_Growth_Stage_Vegetative"])
        + (0.1883 * df["Mulching_Used_No"])             + (0.0142 * df["Mulching_Used_Yes"]))
    df_['logit(P(y=High))']   = (-20.9697 + (10.6947 * df["soil_lt_25"]) + (5.8763 * df["temp_gt_30"])
        + (10.6958 * df["rain_lt_300"]) + (5.7444 * df["wind_gt_10"])
        + (5.0569  * df["Crop_Growth_Stage_Flowering"]) + (-5.3725 * df["Crop_Growth_Stage_Harvest"])
        + (-4.8752 * df["Crop_Growth_Stage_Sowing"])    + (5.1283  * df["Crop_Growth_Stage_Vegetative"])
        + (2.8131  * df["Mulching_Used_No"])             + (-2.8755 * df["Mulching_Used_Yes"]))

NEW_NUMS += ['logit(P(y=Low))', 'logit(P(y=Medium))', 'logit(P(y=High))']

# %%
train.isna().any().any(), test.isna().any().any(), orig.isna().any().any()
# Out:
# (np.False_, np.False_, np.False_)

# %%
# FIX: also merge ORIG stats into orig itself so it can be used in training
for col in CATS + NUMS:
    stats = orig.groupby(col)[TARGET].agg(['mean', 'std']).reset_index()
    stats.columns = [col] + [f"ORIG_{col}_{s}" for s in ['mean', 'std']]
    fill_values = {f"ORIG_{col}_mean": 0.5, f"ORIG_{col}_std": 0}

    for df in [train, test, orig]:   # <-- orig added
        df.merge(stats, on=col, how='left').pipe(lambda d: d.fillna(value=fill_values))

    train = train.merge(stats, on=col, how='left').fillna(value=fill_values)
    test  = test.merge(stats, on=col, how='left').fillna(value=fill_values)
    orig  = orig.merge(stats, on=col, how='left').fillna(value=fill_values)

    NEW_NUMS.extend([f"ORIG_{col}_{s}" for s in ['mean', 'std']])

# %%
# NEW: ratio and interaction features between the main numeric drivers.
# The logit formula tells us these 4 numerics are the key drivers.
# Their ratios capture relative relationships the logit features can't.

EPS = 1e-6
for df in [train, test, orig]:
    # Water availability composite
    df['water_avail']     = df['Soil_Moisture'] + df['Rainfall_mm'] / 300.0
    # Heat-to-moisture stress ratio
    df['heat_stress']     = df['Temperature_C'] / (df['Soil_Moisture'] + EPS)
    # Rain cooling relative to temperature
    df['rain_cool']       = df['Rainfall_mm'] / (df['Temperature_C'] + EPS)
    # Wind evaporation stress
    df['wind_evap']       = df['Wind_Speed_kmh'] * df['Temperature_C'] / 100.0
    # Soil-rain product (both must be present for Low irrigation)
    df['soil_x_rain']     = df['Soil_Moisture'] * df['Rainfall_mm'] / 1000.0
    # High temp + low moisture -> High irrigation signal
    df['temp_x_dryness']  = df['Temperature_C'] * (100 - df['Soil_Moisture']) / 100.0

RATIO_FEATURES = ['water_avail', 'heat_stress', 'rain_cool', 'wind_evap', 'soil_x_rain', 'temp_x_dryness']
NEW_NUMS += RATIO_FEATURES
print(f"Ratio features added: {RATIO_FEATURES}")
# Out:
# Ratio features added: ['water_avail', 'heat_stress', 'rain_cool', 'wind_evap', 'soil_x_rain', 'temp_x_dryness']

# %%
FEATURES = NUMS + CATS + NEW_NUMS + NEW_CATS + NUM_AS_CAT + NON_TE_CATS
print(f'We now have {len(FEATURES)} columns:')
print(FEATURES)
# Out:
# We now have 323 columns:
# ['Soil_pH', 'Soil_Moisture', 'Organic_Carbon', 'Electrical_Conductivity', 'Temperature_C', 'Humidity', 'Rainfall_mm', 'Sunlight_Hours', 'Wind_Speed_kmh', 'Field_Area_hectare', 'Previous_Irrigation_mm', 'Soil_Type', 'Crop_Type', 'Crop_Growth_Stage', 'Season', 'Irrigation_Type', 'Water_Source', 'Mulching_Used', 'Region', 'FREQ_Soil_Type', 'FREQ_Crop_Type', 'FREQ_Crop_Growth_Stage', 'FREQ_Season', 'FREQ_Irrigation_Type', 'FREQ_Water_Source', 'FREQ_Mulching_Used', 'FREQ_Region', 'FREQ_COMBO_Soil_Type_Crop_Type', 'FREQ_COMBO_Soil_Type_Crop_Type_Crop_Growth_Stage', 'FREQ_COMBO_Soil_Type_Crop_Type_Season', 'FREQ_COMBO_Soil_Type_Crop_Type_Irrigation_Type', 'FREQ_COMBO_Soil_Type_Crop_Type_Water_Source', 'FREQ_COMBO_Soil_Type_Crop_Type_Mulching_Used', 'FREQ_COMBO_Soil_Type_Crop_Type_Region', 'FREQ_COMBO_Soil_Type_Crop_Growth_Stage', 'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Season', 'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Irrigation_Type', 'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Water_Source', 'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Mulching_Used', 'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Region', 'FREQ_COMBO_Soil_Type_Season', 'FREQ_COMBO_Soil_Type_Season_Irrigation_Type', 'FREQ_COMBO_Soil_Type_Season_Water_Source', 'FREQ_COMBO_Soil_Type_Season_Mulching_Used', 'FREQ_COMBO_Soil_Type_Season_Region', 'FREQ_COMBO_Soil_Type_Irrigation_Type', 'FREQ_COMBO_Soil_Type_Irrigation_Type_Water_Source', 'FREQ_COMBO_Soil_Type_Irrigation_Type_Mulching_Used', 'FREQ_COMBO_Soil_Type_Irrigation_Type_Region', 'FREQ_COMBO_Soil_Type_Water_Source', 'FREQ_COMBO_Soil_Type_Water_Source_Mulching_Used', 'FREQ_COMBO_Soil_Type_Water_Source_Region', 'FREQ_COMBO_Soil_Type_Mulching_Used', 'FREQ_COMBO_Soil_Type_Mulching_Used_Region', 'FREQ_COMBO_Soil_Type_Region', 'FREQ_COMBO_Crop_Type_Crop_Growth_Stage', 'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Season', 'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Irrigation_Type', 'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Water_Source', 'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Mulching_Used', 'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Region', 'FREQ_COMBO_Crop_Type_Season', 'FREQ_COMBO_Crop_Type_Season_Irrigation_Type', 'FREQ_COMBO_Crop_Type_Season_Water_Source', 'FREQ_COMBO_Crop_Type_Season_Mulching_Used', 'FREQ_COMBO_Crop_Type_Season_Region', 'FREQ_COMBO_Crop_Type_Irrigation_Type', 'FREQ_COMBO_Crop_Type_Irrigation_Type_Water_Source', 'FREQ_COMBO_Crop_Type_Irrigation_Type_Mulching_Used', 'FREQ_COMBO_Crop_Type_Irrigation_Type_Region', 'FREQ_COMBO_Crop_Type_Water_Source', 'FREQ_COMBO_Crop_Type_Water_Source_Mulching_Used', 'FREQ_COMBO_Crop_Type_Water_Source_Region', 'FREQ_COMBO_Crop_Type_Mulching_Used', 'FREQ_COMBO_Crop_Type_Mulching_Used_Region', 'FREQ_COMBO_Crop_Type_Region', 'FREQ_COMBO_Crop_Growth_Stage_Season', 'FREQ_COMBO_Crop_Growth_Stage_Season_Irrigation_Type', 'FREQ_COMBO_Crop_Growth_Stage_Season_Water_Source', 'FREQ_COMBO_Crop_Growth_Stage_Season_Mulching_Used', 'FREQ_COMBO_Crop_Growth_Stage_Season_Region', 'FREQ_COMBO_Crop_Growth_Stage_Irrigation_Type', 'FREQ_COMBO_Crop_Growth_Stage_Irrigation_Type_Water_Source', 'FREQ_COMBO_Crop_Growth_Stage_Irrigation_Type_Mulching_Used', 'FREQ_COMBO_Crop_Growth_Stage_Irrigation_Type_Region', 'FREQ_COMBO_Crop_Growth_Stage_Water_Source', 'FREQ_COMBO_Crop_Growth_Stage_Water_Source_Mulching_Used', 'FREQ_COMBO_Crop_Growth_Stage_Water_Source_Region', 'FREQ_COMBO_Crop_Growth_Stage_Mulching_Used', 'FREQ_COMBO_Crop_Growth_Stage_Mulching_Used_Region', 'FREQ_COMBO_Crop_Growth_Stage_Region', 'FREQ_COMBO_Season_Irrigation_Type', 'FREQ_COMBO_Season_Irrigation_Type_Water_Source', 'FREQ_COMBO_Season_Irrigation_Type_Mulching_Used', 'FREQ_COMBO_Season_Irrigation_Type_Region', 'FREQ_COMBO_Season_Water_Source', 'FREQ_COMBO_Season_Water_Source_Mulching_Used', 'FREQ_COMBO_Season_Water_Source_Region', 'FREQ_COMBO_Season_Mulching_Used', 'FREQ_COMBO_Season_Mulching_Used_Region', 'FREQ_COMBO_Season_Region', 'FREQ_COMBO_Irrigation_Type_Water_Source', 'FREQ_COMBO_Irrigation_Type_Water_Source_Mulching_Used', 'FREQ_COMBO_Irrigation_T ...

# %%
TE_COLUMNS = NUM_AS_CAT + CATS + NEW_CATS
TO_REMOVE += NUM_AS_CAT + CATS + NEW_CATS
QUANTILE_COLUMNS = []

# %% [markdown]
# # Model Training

# %%
np.random.seed(11)

# %%
FOLDS       = 5
INNER_FOLDS = 5

# %%
xgb_params = {
    'n_estimators':    50000,
    'max_depth':       4,
    'colsample_bytree': 0.8,
    'subsample':       0.8,
    'learning_rate':   0.05,     # lowered from 0.1 for more precision
    'n_jobs':          -1,
    'enable_categorical': True,
    'alpha':           5,
    'reg_lambda':      5,
    'gamma':           0.1,      # NEW: min split loss regularisation
    'max_leaves':      30,
    'min_child_weight': 2,
    'tree_method':     'hist',
    'max_bin':         10000,
    'device':          'cuda',
    'objective':       'binary:logistic',  # binary for OVR
}

# %% [markdown]
# # Ordered Target Encoder

# %%
from functools import reduce

class OrderedTE:
    def __init__(self, a=1):
        self.a = a

    def fit(self, train, category_cols=(), target_col='target'):
        self.category_cols = category_cols
        self.classes_ = sorted(train[target_col].unique())
        self.global_prior_ = train[target_col].value_counts(normalize=True).sort_index().values
        self.stats_ = {}

        for c in category_cols:
            stats_list = []
            for k, cls in enumerate(self.classes_):
                y = (train[target_col] == cls).astype(int)
                grp = train[[c]].assign(y=y.values)
                cum_cnt = grp.groupby(c, observed=False)['y'].cumcount()
                cum_sum = grp.groupby(c, observed=False)['y'].cumsum() - grp['y']
                prior = self.global_prior_[k]
                te = (cum_sum + self.a * prior) / (cum_cnt + self.a)
                te_col = f'{c}_TE_cls{cls}'
                train[te_col] = te.values
                agg = grp.groupby(c, observed=False)['y'].agg(count='count', total='sum').reset_index()
                agg.columns = [c, f'{c}_n_{cls}', f'{c}_s_{cls}']
                stats_list.append(agg)
            self.stats_[c] = reduce(lambda l, r: l.merge(r, on=c, how='outer'), stats_list)
        return train

    def transform(self, test):
        for c in self.category_cols:
            test = test.merge(self.stats_[c], on=c, how='left')
            for k, cls in enumerate(self.classes_):
                te_col = f'{c}_TE_cls{cls}'
                n_col, s_col = f'{c}_n_{cls}', f'{c}_s_{cls}'
                prior = self.global_prior_[k]
                if n_col in test.columns:
                    test[te_col] = ((test[s_col] + self.a * prior) / (test[n_col] + self.a)).fillna(prior)
                    test.drop(columns=[n_col, s_col], inplace=True)
                else:
                    test[te_col] = prior
        return test

# %% [markdown]
# # Model Training — StratifiedKFold + Original Data

# %%
def metric(y_true, y_pred, sample_weight=None):
    y_pred = np.argmax(y_pred, axis=1)
    return balanced_accuracy_score(y_true, y_pred, sample_weight=sample_weight)

# %%
# %%time

print(f"\n{'='*80}")
print("TRAINING XGBOOST ONE-VERSUS-REST  (with original data in training)")
print("="*80)

# FIX: StratifiedKFold for class-balanced splits
skf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=11)

# Prepare orig feature columns (same as train, minus id, keep TARGET for TE fit)
orig_train = orig[FEATURES + [TARGET]].reset_index(drop=True).copy()

oof         = np.zeros((len(train), 3))
pred        = np.zeros((len(test),  3))
importances = {0: [], 1: [], 2: []}
metric_folds = []

for i, (train_index, val_index) in enumerate(skf.split(train, train[TARGET])):
    print(f"\n{'='*60}")
    print(f"Fold {i+1}/{FOLDS}")
    print('='*60)

    # ── TRAIN/VAL SPLIT ──────────────────────────────────────────
    X_train = train.loc[train_index, FEATURES + [TARGET]].reset_index(drop=True).copy()
    y_train_multiclass = train.loc[train_index, TARGET].values

    X_val = train.loc[val_index, FEATURES].reset_index(drop=True).copy()
    y_val_multiclass = train.loc[val_index, TARGET].values

    # FIX: include orig in training data
    # We concat BEFORE TE so the TE is fitted on train-fold only,
    # then transform orig separately and concatenate for actual model fit.
    X_orig_for_te = orig_train.copy()  # has TARGET for TE fit reference
    X_test = test[FEATURES].reset_index(drop=True).copy()

    # ── TARGET ENCODING ──────────────────────────────────────────
    target_encoder = OrderedTE(a=1)
    X_train = target_encoder.fit(X_train, category_cols=TE_COLUMNS, target_col=TARGET)
    X_val   = target_encoder.transform(X_val)
    X_test  = target_encoder.transform(X_test)

    # Transform orig with the same TE (fitted on train fold only)
    X_orig_features = X_orig_for_te.drop(TARGET, axis=1)
    X_orig_features = target_encoder.transform(X_orig_features)
    y_orig_multiclass = X_orig_for_te[TARGET].values

    # ── CONVERT CATS FOR XGBOOST ─────────────────────────────────
    for df in [X_train, X_val, X_test, X_orig_features]:
        df[CATS + NEW_CATS + NUM_AS_CAT + NON_TE_CATS] = (
            df[CATS + NEW_CATS + NUM_AS_CAT + NON_TE_CATS]
            .astype(str).astype("category")
        )

    # Drop raw cat columns (now replaced by TE)
    for df in [X_train, X_val, X_test, X_orig_features]:
        drop_cols = [c for c in TO_REMOVE if c in df.columns]
        df.drop(drop_cols, axis=1, inplace=True)

    X_train = X_train.drop([TARGET], axis=1)
    COLS = X_train.columns

    # ── CONCAT train-fold + orig for model training ───────────────
    X_train_full = pd.concat([X_train, X_orig_features[COLS]], axis=0).reset_index(drop=True)
    y_train_full  = np.concatenate([y_train_multiclass, y_orig_multiclass])

    # ── TRAIN 3 BINARY OVR MODELS ────────────────────────────────
    fold_oof_probs  = np.zeros((len(X_val),    3))
    fold_test_probs = np.zeros((len(X_test),   3))

    for class_idx in range(3):
        print(f"\n  Training binary classifier for class {class_idx}")

        y_train_binary = (y_train_full == class_idx).astype(int)
        y_val_binary   = (y_val_multiclass == class_idx).astype(int)

        s_wei_train = compute_sample_weight('balanced', y_train_binary)

        model = xgb.XGBClassifier(
            **xgb_params,
            eval_metric='logloss',
            callbacks=[
                xgb.callback.EarlyStopping(
                    rounds=300, metric_name='logloss', save_best=True
                )
            ],
        )
        model.fit(
            X_train_full, y_train_binary,
            sample_weight=s_wei_train,
            eval_set=[(X_val, y_val_binary)],
            verbose=1000
        )

        fold_oof_probs[:, class_idx]  = model.predict_proba(X_val)[:, 1]
        fold_test_probs[:, class_idx] = model.predict_proba(X_test[COLS])[:, 1]

        importances[class_idx].append(model.get_booster().get_score(importance_type='gain'))

    # Normalise to sum-to-1
    fold_oof_probs  /= fold_oof_probs.sum(axis=1,  keepdims=True)
    fold_test_probs /= fold_test_probs.sum(axis=1,  keepdims=True)

    oof[val_index] = fold_oof_probs
    pred += fold_test_probs

    bal_acc_fold = metric(y_val_multiclass, fold_oof_probs)
    metric_folds.append(bal_acc_fold)
    print(f"\nFold {i+1} Validation Balanced Accuracy: {bal_acc_fold:.5f}")

    del X_train, X_val, X_test, X_train_full, X_orig_features
    del y_train_multiclass, y_val_multiclass, y_train_full, y_orig_multiclass
    gc.collect()

pred /= FOLDS
# Out:
# ================================================================================
# TRAINING XGBOOST ONE-VERSUS-REST  (with original data in training)
# ================================================================================
#
# ============================================================
# Fold 1/5
# ============================================================
#
#   Training binary classifier for class 0
# [0]	validation_0-logloss:0.64654
# [855]	validation_0-logloss:0.03798
#
#   Training binary classifier for class 1
# [0]	validation_0-logloss:0.64728
# [1000]	validation_0-logloss:0.04868
# [2000]	validation_0-logloss:0.04865
# [2015]	validation_0-logloss:0.04865
#
#   Training binary classifier for class 2
# [0]	validation_0-logloss:0.64752
# [1000]	validation_0-logloss:0.01400
# [2000]	validation_0-logloss:0.01161
# [2333]	validation_0-logloss:0.01168
#
# Fold 1 Validation Balanced Accuracy: 0.97380
#
# ============================================================
# Fold 2/5
# ============================================================
#
#   Training binary classifier for class 0
# [0]	validation_0-logloss:0.64653
# [794]	validation_0-logloss:0.03828
#
#   Training binary classifier for class 1
# [0]	validation_0-logloss:0.64729
# [1000]	validation_0-logloss:0.04896
# [1531]	validation_0-logloss:0.04891
#
#   Training binary classifier for class 2
# [0]	validation_0-logloss:0.64746
# [1000]	validation_0-logloss:0.01277
# [2000]	validation_0-logloss:0.01128
# [2210]	validation_0-logloss:0.01136
#
# Fold 2 Validation Balanced Accuracy: 0.97255
#
# ============================================================
# Fold 3/5
# ============================================================
#
#   Training binary classifier for class 0
# [0]	validation_0-logloss:0.64654
# [708]	validation_0-logloss:0.03997
#
#   Training binary classifier for class 1
# [0]	validation_0-logloss:0.64730
# [1000]	validation_0-logloss:0.05097
# [1225]	validation_0-logloss:0.05092
#
#   Training binary classifier for class 2
# [0]	validation_0-logloss:0.64747
# [1000]	validation_0-logloss:0.01215
# [2000]	validation_0-logloss:0.01088
# [2073]	validation_0-logloss:0.01088
#
# Fold 3 Validation Balanced Accuracy: 0.96937
#
# ============================================================
# Fold 4/5
# ============================================================
#
#   Training binary classifier for class 0
# [0]	validation_0-logloss:0.64650
# [856]	validation_0-logloss:0.03751
#
#   Training binary classifier for class 1
# [0]	validation_0-logloss:0.64726
# [1000]	validation_0-logloss:0.04790
# [1670]	validation_0-logloss:0.04793
#
#   Training binary classifier for class 2
# [0]	validation_0-logloss:0.64761
# [1000]	validation_0-logloss:0.01184
# [2000]	validation_0-logloss:0.01031
# [2187]	validation_0-logloss:0.01038
#
# Fold 4 Validation Balanced Accuracy: 0.97232
#
# ============================================================
# Fold 5/5
# ============================================================
#
#   Training binary classifier for class 0
# [0]	validation_0-logloss:0.64655
# [763]	validation_0-logloss:0.03935
#
#   Training binary classifier for class 1
# [0]	validation_0-logloss:0.64730
# [1000]	validation_0-logloss:0.05019
# [1444]	validation_0-logloss:0.05024
#
#   Training binary classifier for class 2
# [0]	validation_0-logloss:0.64748
# [1000]	validation_0-logloss:0.01282
# [1907]	validation_0-logloss:0.01163
#
# Fold 5 Validation Balanced Accuracy: 0.97094

# %%
print(f'Fold Balanced Accuracy {np.mean(metric_folds):.5f} +- {np.std(metric_folds):.5f}')
true = train[TARGET].values
print(f'Overall Balanced Accuracy: {metric(true, oof)}')
# Out:
# Fold Balanced Accuracy 0.97180 +- 0.00151
# Overall Balanced Accuracy: 0.9717963613027196

# %%
print(f'\nIn total, we used {len(COLS)} features, Wow!\n')
print(list(COLS))
# Out:
# In total, we used 669 features, Wow!
#
# ['Soil_pH', 'Soil_Moisture', 'Organic_Carbon', 'Electrical_Conductivity', 'Temperature_C', 'Humidity', 'Rainfall_mm', 'Sunlight_Hours', 'Wind_Speed_kmh', 'Field_Area_hectare', 'Previous_Irrigation_mm', 'FREQ_Soil_Type', 'FREQ_Crop_Type', 'FREQ_Crop_Growth_Stage', 'FREQ_Season', 'FREQ_Irrigation_Type', 'FREQ_Water_Source', 'FREQ_Mulching_Used', 'FREQ_Region', 'FREQ_COMBO_Soil_Type_Crop_Type', 'FREQ_COMBO_Soil_Type_Crop_Type_Crop_Growth_Stage', 'FREQ_COMBO_Soil_Type_Crop_Type_Season', 'FREQ_COMBO_Soil_Type_Crop_Type_Irrigation_Type', 'FREQ_COMBO_Soil_Type_Crop_Type_Water_Source', 'FREQ_COMBO_Soil_Type_Crop_Type_Mulching_Used', 'FREQ_COMBO_Soil_Type_Crop_Type_Region', 'FREQ_COMBO_Soil_Type_Crop_Growth_Stage', 'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Season', 'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Irrigation_Type', 'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Water_Source', 'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Mulching_Used', 'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Region', 'FREQ_COMBO_Soil_Type_Season', 'FREQ_COMBO_Soil_Type_Season_Irrigation_Type', 'FREQ_COMBO_Soil_Type_Season_Water_Source', 'FREQ_COMBO_Soil_Type_Season_Mulching_Used', 'FREQ_COMBO_Soil_Type_Season_Region', 'FREQ_COMBO_Soil_Type_Irrigation_Type', 'FREQ_COMBO_Soil_Type_Irrigation_Type_Water_Source', 'FREQ_COMBO_Soil_Type_Irrigation_Type_Mulching_Used', 'FREQ_COMBO_Soil_Type_Irrigation_Type_Region', 'FREQ_COMBO_Soil_Type_Water_Source', 'FREQ_COMBO_Soil_Type_Water_Source_Mulching_Used', 'FREQ_COMBO_Soil_Type_Water_Source_Region', 'FREQ_COMBO_Soil_Type_Mulching_Used', 'FREQ_COMBO_Soil_Type_Mulching_Used_Region', 'FREQ_COMBO_Soil_Type_Region', 'FREQ_COMBO_Crop_Type_Crop_Growth_Stage', 'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Season', 'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Irrigation_Type', 'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Water_Source', 'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Mulching_Used', 'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Region', 'FREQ_COMBO_Crop_Type_Season', 'FREQ_COMBO_Crop_Type_Season_Irrigation_Type', 'FREQ_COMBO_Crop_Type_Season_Water_Source', 'FREQ_COMBO_Crop_Type_Season_Mulching_Used', 'FREQ_COMBO_Crop_Type_Season_Region', 'FREQ_COMBO_Crop_Type_Irrigation_Type', 'FREQ_COMBO_Crop_Type_Irrigation_Type_Water_Source', 'FREQ_COMBO_Crop_Type_Irrigation_Type_Mulching_Used', 'FREQ_COMBO_Crop_Type_Irrigation_Type_Region', 'FREQ_COMBO_Crop_Type_Water_Source', 'FREQ_COMBO_Crop_Type_Water_Source_Mulching_Used', 'FREQ_COMBO_Crop_Type_Water_Source_Region', 'FREQ_COMBO_Crop_Type_Mulching_Used', 'FREQ_COMBO_Crop_Type_Mulching_Used_Region', 'FREQ_COMBO_Crop_Type_Region', 'FREQ_COMBO_Crop_Growth_Stage_Season', 'FREQ_COMBO_Crop_Growth_Stage_Season_Irrigation_Type', 'FREQ_COMBO_Crop_Growth_Stage_Season_Water_Source', 'FREQ_COMBO_Crop_Growth_Stage_Season_Mulching_Used', 'FREQ_COMBO_Crop_Growth_Stage_Season_Region', 'FREQ_COMBO_Crop_Growth_Stage_Irrigation_Type', 'FREQ_COMBO_Crop_Growth_Stage_Irrigation_Type_Water_Source', 'FREQ_COMBO_Crop_Growth_Stage_Irrigation_Type_Mulching_Used', 'FREQ_COMBO_Crop_Growth_Stage_Irrigation_Type_Region', 'FREQ_COMBO_Crop_Growth_Stage_Water_Source', 'FREQ_COMBO_Crop_Growth_Stage_Water_Source_Mulching_Used', 'FREQ_COMBO_Crop_Growth_Stage_Water_Source_Region', 'FREQ_COMBO_Crop_Growth_Stage_Mulching_Used', 'FREQ_COMBO_Crop_Growth_Stage_Mulching_Used_Region', 'FREQ_COMBO_Crop_Growth_Stage_Region', 'FREQ_COMBO_Season_Irrigation_Type', 'FREQ_COMBO_Season_Irrigation_Type_Water_Source', 'FREQ_COMBO_Season_Irrigation_Type_Mulching_Used', 'FREQ_COMBO_Season_Irrigation_Type_Region', 'FREQ_COMBO_Season_Water_Source', 'FREQ_COMBO_Season_Water_Source_Mulching_Used', 'FREQ_COMBO_Season_Water_Source_Region', 'FREQ_COMBO_Season_Mulching_Used', 'FREQ_COMBO_Season_Mulching_Used_Region', 'FREQ_COMBO_Season_Region', 'FREQ_COMBO_Irrigation_Type_Water_Source', 'FREQ_COMBO_Irrigation_Type_Water_Source_Mulching_Used', 'FREQ_COMBO_Irrigation_Type_Water_Source_Region', 'FREQ_COMBO_Irrigation_Type_Mulching_Used', 'FREQ_COMBO_Irrigation_Type_Mulching_Used_Region' ...

# %% [markdown]
# # XGB Feature Importance (per class)

# %%
all_importances = []
for class_idx in range(3):
    for fold_imp in importances[class_idx]:
        all_importances.append(fold_imp)

feature_names = all_importances[0].keys()
importances_mean = [
    np.mean([imp[feat] if feat in imp else 0 for imp in all_importances])
    for feat in feature_names
]

# %%
indices = np.argsort(importances_mean)
sorted_features   = np.array(list(feature_names))[indices][-100:]
sorted_importance = np.array(importances_mean)[indices][-100:]

plt.figure(figsize=(15, 30))
plt.barh(range(len(sorted_importance)), sorted_importance)
plt.yticks(range(len(sorted_features)), sorted_features)
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.title('XGBoost Feature Importance (Sorted)')
plt.tight_layout()
plt.show()

# %%
dict(sorted(zip(feature_names, [float(f) for f in importances_mean]), key=lambda x: -x[1]))
# Out:
# {'logit(P(y=High))': 7943.913297526042,
#  'ORIG_Crop_Growth_Stage_mean': 6994.106847127278,
#  'logit(P(y=Low))': 6059.9915771484375,
#  'logit(P(y=Medium))': 959.1695149739584,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Season_TE_cls1': 338.7967740058899,
#  'COMBO_Crop_Growth_Stage_Mulching_Used_TE_cls1': 154.84401245117186,
#  'Temperature_C_digit1_TE_cls0': 139.59584630330403,
#  'COMBO_Crop_Type_Mulching_Used_TE_cls1': 112.64656607309978,
#  'COMBO_Soil_Type_Mulching_Used_Region_TE_cls0': 106.14823665618897,
#  'CAT_Rainfall_mm_TE_cls2': 99.8804407119751,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Mulching_Used_TE_cls0': 99.74662361145019,
#  'Temperature_C_digit1_TE_cls2': 99.31874319712321,
#  'COMBO_Crop_Growth_Stage_Mulching_Used_TE_cls2': 91.83167266845703,
#  'COMBO_Crop_Growth_Stage_Season_Mulching_Used_TE_cls1': 88.67110474904378,
#  'COMBO_Crop_Growth_Stage_Water_Source_Mulching_Used_TE_cls1': 88.04234759012859,
#  'COMBO_Crop_Growth_Stage_Mulching_Used_Region_TE_cls1': 87.5170342763265,
#  'Wind_Speed_kmh_digit1_TE_cls1': 84.59279572168985,
#  'COMBO_Crop_Growth_Stage_Irrigation_Type_Mulching_Used_TE_cls1': 82.42144686381022,
#  'heat_stress': 78.21922620137532,
#  'Mulching_Used_TE_cls0': 78.0382297317187,
#  'COMBO_Water_Source_Mulching_Used_TE_cls0': 72.52164316177368,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Mulching_Used_TE_cls1': 71.81841773986817,
#  'COMBO_Crop_Growth_Stage_Mulching_Used_TE_cls0': 69.80258210500081,
#  'COMBO_Crop_Growth_Stage_Water_Source_Mulching_Used_TE_cls0': 69.50327695210775,
#  'COMBO_Crop_Growth_Stage_Irrigation_Type_Mulching_Used_TE_cls0': 64.01727307637533,
#  'CAT_Rainfall_mm_TE_cls1': 62.07769037882487,
#  'Wind_Speed_kmh_digit1_TE_cls0': 58.973956203460695,
#  'Temperature_C': 57.977448018391925,
#  'COMBO_Crop_Growth_Stage_Season_Mulching_Used_TE_cls0': 57.577687708536786,
#  'CAT_Rainfall_mm_TE_cls0': 55.74737714131673,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Mulching_Used_TE_cls0': 55.69252815246582,
#  'wind_evap': 55.01311391194661,
#  'COMBO_Soil_Type_Water_Source_Mulching_Used_TE_cls0': 52.00837027231852,
#  'COMBO_Crop_Growth_Stage_Water_Source_Mulching_Used_TE_cls2': 51.659749285380045,
#  'Temperature_C_digit1_TE_cls1': 51.13456656138102,
#  'COMBO_Soil_Type_Mulching_Used_TE_cls1': 50.351605383555096,
#  'Rainfall_mm': 47.672922134399414,
#  'COMBO_Crop_Growth_Stage_Season_Water_Source_TE_cls0': 46.025545342763266,
#  'CAT_Temperature_C_TE_cls2': 45.08470007578532,
#  'ORIG_Rainfall_mm_mean': 44.33383852640788,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Mulching_Used_TE_cls1': 44.22027467091878,
#  'CAT_Organic_Carbon_TE_cls2': 42.06192735036214,
#  'COMBO_Water_Source_Mulching_Used_Region_TE_cls1': 39.69408394495646,
#  'CAT_Soil_Moisture_TE_cls0': 39.225003973642984,
#  'COMBO_Crop_Growth_Stage_Mulching_Used_Region_TE_cls0': 39.0000293413798,
#  'Wind_Speed_kmh_digit1_TE_cls2': 36.940819613138835,
#  'rain_cool': 36.88254890441895,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Mulching_Used_TE_cls2': 36.57829755147298,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Water_Source_TE_cls1': 36.280070781707764,
#  'CAT_Previous_Irrigation_mm_TE_cls0': 35.91728954315185,
#  'CAT_Humidity_TE_cls0': 34.19965883890788,
#  'COMBO_Crop_Growth_Stage_Season_Mulching_Used_TE_cls2': 33.707458305358884,
#  'CAT_Soil_Moisture_TE_cls1': 31.195282173156738,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Water_Source_TE_cls2': 30.77290045420329,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Mulching_Used_TE_cls2': 30.494475746154784,
#  'CAT_Previous_Irrigation_mm_TE_cls1': 30.065782165527345,
#  'CAT_Previous_Irrigation_mm_TE_cls2': 30.039839235941567,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Water_Source_TE_cls0': 28.24089911778768,
#  'CAT_Soil_Moisture_TE_cls2': 28.067042605082193,
#  'Rainfall_mm_digit2_TE_cls2': 27.139990615844727,
#  'CAT_Temperature_C_TE_cls1': 26.882427469889322,
#  'Humidity_digit1_TE_cls2': 26.656017939249676,
#  'Sunlight_Hours_digit0_TE_cls2': 26.37182725270589,
#  'wind_gt_10_TE_cls1': 26.344168535868327,
#  'COMBO_Soil_Type_Mulching_Used_TE_cls2': 26.079709021250405,
#  'COMBO_Irrigation_Type_Water_Source_Mulching_Used_TE_cls1': 25.534714380900066,
#  'COMBO_Season_Mulching_Used_Region_TE_cls0': 25.225960350036623,
#  'CAT_Electrical_Conductivity_TE_cls2': 25.002324485778807,
#  'COMBO_Crop_Type_Water_Source_Mulching_Used_TE_cls2': 24.952055962880454,
#  'COMBO_Water_Source_Mulching_Used_Region_TE_cls0': 24.92490202585856,
#  'Soil_Moisture': 24.803407351175945,
#  'CAT_Humidity_TE_cls1': 24.61807975769043,
#  'soil_x_rain': 23.783338197072347,
#  'COMBO_Crop_Growth_Stage_Mulching_Used_Region_TE_cls2': 23.43467648824056,
#  'CAT_Humidity_TE_cls2': 23.335678482055663,
#  'COMBO_Soil_Type_Irrigation_Type_Mulching_Used_TE_cls2': 22.67626142501831,
#  'CAT_Soil_pH_TE_cls2': 22.60966771443685,
#  'COMBO_Crop_Growth_Stage_Water_Source_Region_TE_cls0': 22.59121478398641,
#  'Previous_Irrigation_mm': 22.489877065022785,
#  'wind_gt_10_TE_cls2': 22.01435791651408,
#  'CAT_Temperature_C_TE_cls0': 21.827458953857423,
#  'COMBO_Mulching_Used_Region_TE_cls2': 21.455908075968424,
#  'Mulching_Used_TE_cls2': 21.088035265604656,
#  'temp_x_dryness': 21.073188304901123,
#  'COMBO_Water_Source_Mulching_Used_TE_cls1': 21.019854068756104,
#  'temp_gt_30_TE_cls2': 20.805171076456705,
#  'Previous_Irrigation_mm_digit1_TE_cls2': 20.187320645650228,
#  'Temperature_C_digit0_TE_cls2': 19.80107593536377,
#  'COMBO_Water_Source_Mulching_Used_TE_cls2': 19.701278241475425,
#  'COMBO_Crop_Type_Irrigation_Type_Mulching_Used_TE_cls2': 19.492783959706625,
#  'CAT_Soil_pH_TE_cls1': 19.485292053222658,
#  'Soil_Moisture_digit0_TE_cls1': 19.42825438181559,
#  'COMBO_Season_Irrigation_Type_Mulching_Used_TE_cls2': 19.399960295359293,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Irrigation_Type_TE_cls1': 19.39261776606242,
#  'soil_lt_25_TE_cls0': 19.15829308827718,
#  'Wind_Speed_kmh': 19.056959533691405,
#  'rain_lt_300_TE_cls1': 18.718974431355793,
#  'COMBO_Crop_Growth_Stage_Irrigation_Type_Mulching_Used_TE_cls2': 18.64229653676351,
#  'Humidity_digit0_TE_cls2': 18.509159787495932,
#  'COMBO_Soil_Type_Mulching_Used_Region_TE_cls1': 18.493982632954914,
#  'Humidity_digit1_TE_cls0': 18.324337450663247,
#  'FREQ_COMBO_Soil_Type_Water_Source': 18.268705495198567,
#  'Soil_pH_digit0_TE_cls2': 18.267833932240805,
#  'Soil_Moisture_digit0_TE_cls2': 18.021781412760415,
#  'COMBO_Season_Water_Source_Mulching_Used_TE_cls0': 17.875741895039877,
#  'COMBO_Crop_Growth_Stage_Water_Source_Region_TE_cls1': 17.868924395243326,
#  'ORIG_Organic_Carbon_std': 17.733186213175454,
#  'rain_lt_300_TE_cls0': 17.7090425491333,
#  'COMBO_Irrigation_Type_Water_Source_Mulching_Used_TE_cls2': 17.59464340209961,
#  'Previous_Irrigation_mm_digit0_TE_cls2': 17.562009938557942,
#  'Humidity': 17.484581438700356,
#  'Wind_Speed_kmh_digit0_TE_cls2': 17.382896423339844,
#  'Water_Source_TE_cls1': 17.34553197224935,
#  'COMBO_Soil_Type_Crop_Type_Mulching_Used_TE_cls2': 17.1151735941569,
#  'COMBO_Crop_Type_Season_Water_Source_TE_cls2': 17.051378027598062,
#  'COMBO_Soil_Type_Mulching_Used_TE_cls0': 16.944440778096517,
#  'CAT_Sunlight_Hours_TE_cls2': 16.912115160624186,
#  'CAT_Wind_Speed_kmh_TE_cls1': 16.842418162027993,
#  'soil_lt_25_TE_cls1': 16.762647438049317,
#  'Soil_pH_digit0_TE_cls1': 16.715976492563883,
#  'Sunlight_Hours_digit0_TE_cls1': 16.60810753504435,
#  'COMBO_Crop_Type_Water_Source_TE_cls2': 16.607777277628582,
#  'CAT_Organic_Carbon_TE_cls1': 16.602373186747233,
#  'COMBO_Season_Irrigation_Type_Region_TE_cls1': 16.529182211558023,
#  'temp_gt_30_TE_cls0': 16.51765530904134,
#  'Mulching_Used_TE_cls1': 16.354199854532876,
#  'water_avail': 16.312797355651856,
#  'COMBO_Soil_Type_Crop_Growth_Stage_TE_cls2': 16.162710189819336,
#  'Sunlight_Hours_digit0_TE_cls0': 15.87244955698649,
#  'Soil_Moisture_digit1_TE_cls1': 15.839105860392253,
#  'COMBO_Soil_Type_Irrigation_Type_Mulching_Used_TE_cls0': 15.599364344278971,
#  'Soil_Moisture_digit1_TE_cls0': 15.568074480692546,
#  'Irrigation_Type_TE_cls1': 15.478490098317463,
#  'temp_gt_30_TE_cls1': 15.437050501505533,
#  'COMBO_Water_Source_Mulching_Used_Region_TE_cls2': 15.415922514597575,
#  'COMBO_Soil_Type_Water_Source_Mulching_Used_TE_cls1': 15.38195374806722,
#  'Previous_Irrigation_mm_digit2_TE_cls1': 15.356442070007324,
#  'CAT_Soil_pH_TE_cls0': 15.203100395202636,
#  'Electrical_Conductivity': 15.193976720174154,
#  'Wind_Speed_kmh_digit0_TE_cls0': 14.951073837280273,
#  'COMBO_Crop_Growth_Stage_Irrigation_Type_Water_Source_TE_cls1': 14.925945917765299,
#  'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Irrigation_Type': 14.912162272135417,
#  'Temperature_C_digit-1_TE_cls2': 14.900664265950521,
#  'Previous_Irrigation_mm_digit0_TE_cls0': 14.750001589457193,
#  'COMBO_Season_Mulching_Used_TE_cls1': 14.729545656840006,
#  'FREQ_COMBO_Irrigation_Type_Mulching_Used': 14.725244265794753,
#  'Rainfall_mm_digit2_TE_cls0': 14.718517049153645,
#  'CAT_Wind_Speed_kmh_TE_cls0': 14.715492884318033,
#  'COMBO_Crop_Type_Season_Irrigation_Type_TE_cls1': 14.667525800069173,
#  'COMBO_Crop_Growth_Stage_Season_Water_Source_TE_cls1': 14.654089323679607,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Water_Source_TE_cls2': 14.647453435262044,
#  'COMBO_Irrigation_Type_Region_TE_cls1': 14.646666304270427,
#  'Wind_Speed_kmh_digit0_TE_cls1': 14.5849609375,
#  'Humidity_digit1_TE_cls1': 14.557216199239095,
#  'FREQ_COMBO_Crop_Growth_Stage_Season_Mulching_Used': 14.463639259338379,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Water_Source_TE_cls0': 14.440747006734211,
#  'COMBO_Soil_Type_Crop_Type_Crop_Growth_Stage_TE_cls2': 14.368039067586263,
#  'COMBO_Crop_Type_Mulching_Used_TE_cls0': 14.36545623143514,
#  'Soil_Moisture_digit0_TE_cls0': 14.290325768788655,
#  'Humidity_digit0_TE_cls0': 14.231510353088378,
#  'COMBO_Soil_Type_Crop_Type_Water_Source_TE_cls2': 14.225687980651855,
#  'COMBO_Irrigation_Type_Mulching_Used_TE_cls2': 14.206738058725993,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Irrigation_Type_TE_cls0': 14.148925272623698,
#  'Soil_pH': 14.136896387736003,
#  'COMBO_Crop_Growth_Stage_Irrigation_Type_Region_TE_cls1': 14.074461364746094,
#  'COMBO_Soil_Type_Water_Source_Mulching_Used_TE_cls2': 14.072469456990559,
#  'COMBO_Crop_Growth_Stage_Season_Region_TE_cls0': 13.986527379353841,
#  'COMBO_Crop_Type_Irrigation_Type_TE_cls1': 13.92620632648468,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Region_TE_cls2': 13.881079483032227,
#  'CAT_Field_Area_hectare_TE_cls0': 13.866135311126708,
#  'COMBO_Irrigation_Type_Mulching_Used_Region_TE_cls2': 13.838721179962159,
#  'COMBO_Crop_Type_Crop_Growth_Stage_TE_cls2': 13.8056489944458,
#  'COMBO_Crop_Growth_Stage_Season_Irrigation_Type_TE_cls1': 13.764067300160725,
#  'COMBO_Season_Water_Source_Mulching_Used_TE_cls1': 13.742160733540853,
#  'FREQ_COMBO_Crop_Growth_Stage_Mulching_Used': 13.679545291264851,
#  'CAT_Field_Area_hectare_TE_cls2': 13.615217685699463,
#  'CAT_Electrical_Conductivity_TE_cls1': 13.564650726318359,
#  'rain_lt_300_TE_cls2': 13.546071116129557,
#  'COMBO_Crop_Growth_Stage_Irrigation_Type_Region_TE_cls0': 13.518476072947184,
#  'Previous_Irrigation_mm_digit1_TE_cls0': 13.512926610310872,
#  'COMBO_Crop_Type_Irrigation_Type_Water_Source_TE_cls2': 13.460878213246664,
#  'Rainfall_mm_digit-1_TE_cls0': 13.460650030771891,
#  'COMBO_Crop_Type_Season_Mulching_Used_TE_cls2': 13.343520736694336,
#  'Soil_Moisture_digit1_TE_cls2': 13.339798927307129,
#  'COMBO_Crop_Type_Water_Source_Mulching_Used_TE_cls1': 13.332625611623127,
#  'Organic_Carbon_digit-4_TE_cls0': 13.319947369893391,
#  'COMBO_Water_Source_Region_TE_cls0': 13.290299765268962,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Irrigation_Type_TE_cls1': 13.273443094889323,
#  'Rainfall_mm_digit3_TE_cls0': 13.242102495829265,
#  'COMBO_Crop_Type_Water_Source_Mulching_Used_TE_cls0': 13.197804355621338,
#  'COMBO_Mulching_Used_Region_TE_cls1': 13.174077320098878,
#  'ORIG_Organic_Carbon_mean': 13.171665891011555,
#  'Rainfall_mm_digit1_TE_cls1': 13.164294370015462,
#  'COMBO_Crop_Growth_Stage_Irrigation_Type_Water_Source_TE_cls0': 13.129277229309082,
#  'COMBO_Mulching_Used_Region_TE_cls0': 13.100816504160564,
#  'Sunlight_Hours_digit1_TE_cls0': 13.090437730153402,
#  'Previous_Irrigation_mm_digit0_TE_cls1': 12.9832275390625,
#  'CAT_Wind_Speed_kmh_TE_cls2': 12.971557807922363,
#  'COMBO_Crop_Growth_Stage_Water_Source_TE_cls0': 12.953219827016195,
#  'COMBO_Crop_Type_Mulching_Used_TE_cls2': 12.859161059061686,
#  'Irrigation_Type_TE_cls0': 12.852311070760091,
#  'Soil_Type_TE_cls1': 12.851712512969971,
#  'CAT_Organic_Carbon_TE_cls0': 12.807358010609944,
#  'wind_gt_10_TE_cls0': 12.74663823445638,
#  'Humidity_digit0_TE_cls1': 12.694199498494466,
#  'Rainfall_mm_digit2_TE_cls1': 12.657512029012045,
#  'FREQ_COMBO_Water_Source_Mulching_Used_Region': 12.646564292907716,
#  'FREQ_COMBO_Crop_Type_Water_Source_Mulching_Used': 12.640023454030354,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Irrigation_Type_TE_cls0': 12.610235118865967,
#  'COMBO_Crop_Type_Irrigation_Type_Region_TE_cls1': 12.505122852325439,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Region_TE_cls1': 12.481560738881429,
#  'COMBO_Irrigation_Type_Mulching_Used_TE_cls1': 12.478025849660238,
#  'COMBO_Crop_Growth_Stage_Season_TE_cls0': 12.47712984085083,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Irrigation_Type_TE_cls2': 12.400048732757568,
#  'ORIG_Humidity_mean': 12.395996316274006,
#  'COMBO_Crop_Type_Mulching_Used_Region_TE_cls2': 12.357732073465984,
#  'COMBO_Season_Irrigation_Type_TE_cls1': 12.331629498799641,
#  'FREQ_COMBO_Soil_Type_Region': 12.315796391169231,
#  'Wind_Speed_kmh_digit-1_TE_cls0': 12.310821533203125,
#  'CAT_Sunlight_Hours_TE_cls0': 12.308260281880697,
#  'COMBO_Irrigation_Type_Water_Source_TE_cls2': 12.277120812733967,
#  'Rainfall_mm_digit0_TE_cls2': 12.269060325622558,
#  'CAT_Electrical_Conductivity_TE_cls0': 12.1500231107076,
#  'COMBO_Crop_Growth_Stage_Water_Source_Region_TE_cls2': 12.093193531036377,
#  'COMBO_Soil_Type_Water_Source_TE_cls2': 12.089539051055908,
#  'FREQ_COMBO_Season_Water_Source_Region': 12.085695997873943,
#  'ORIG_Electrical_Conductivity_std': 12.083008416493733,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Season_TE_cls2': 12.076625728607178,
#  'Soil_Moisture_digit-1_TE_cls2': 12.051783307393391,
#  'Previous_Irrigation_mm_digit-3_TE_cls2': 12.017785771687825,
#  'Electrical_Conductivity_digit-3_TE_cls1': 12.01605354944865,
#  'Soil_Type_TE_cls0': 12.011566829681396,
#  'Sunlight_Hours_digit1_TE_cls1': 12.010599136352539,
#  'Field_Area_hectare_digit0_TE_cls2': 11.984857940673828,
#  'COMBO_Crop_Growth_Stage_Water_Source_TE_cls2': 11.95949182510376,
#  'COMBO_Crop_Growth_Stage_Irrigation_Type_Water_Source_TE_cls2': 11.942569239934285,
#  'CAT_Sunlight_Hours_TE_cls1': 11.909844970703125,
#  'ORIG_Field_Area_hectare_mean': 11.908625221252441,
#  'COMBO_Soil_Type_Crop_Growth_Stage_TE_cls0': 11.90348196029663,
#  'CAT_Field_Area_hectare_TE_cls1': 11.900407059987385,
#  'Organic_Carbon_digit-2_TE_cls2': 11.887524731953938,
#  'ORIG_Crop_Growth_Stage_std': 11.880555852254231,
#  'COMBO_Soil_Type_Season_Water_Source_TE_cls2': 11.866654713948568,
#  'Temperature_C_digit0_TE_cls1': 11.815477244059245,
#  'COMBO_Crop_Growth_Stage_Irrigation_Type_TE_cls2': 11.809132251143456,
#  'COMBO_Crop_Type_Crop_Growth_Stage_TE_cls0': 11.805888907114666,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Irrigation_Type_TE_cls2': 11.80156857172648,
#  'Previous_Irrigation_mm_digit-1_TE_cls1': 11.794914245605469,
#  'ORIG_Soil_Moisture_mean': 11.74509433110555,
#  'ORIG_Temperature_C_std': 11.729974778493245,
#  'Rainfall_mm_digit0_TE_cls0': 11.727300198872884,
#  'FREQ_COMBO_Crop_Type_Water_Source': 11.70738870302836,
#  'COMBO_Soil_Type_Irrigation_Type_Water_Source_TE_cls1': 11.69478530883789,
#  'Organic_Carbon_digit-4_TE_cls1': 11.684131526947022,
#  'COMBO_Crop_Type_Water_Source_Region_TE_cls0': 11.662420908610025,
#  'COMBO_Crop_Type_Mulching_Used_Region_TE_cls0': 11.661365127563476,
#  'COMBO_Season_Irrigation_Type_Water_Source_TE_cls0': 11.64790719350179,
#  'COMBO_Soil_Type_Crop_Type_Mulching_Used_TE_cls0': 11.637444909413656,
#  'Humidity_digit-1_TE_cls1': 11.63270934422811,
#  'COMBO_Crop_Type_Season_Irrigation_Type_TE_cls0': 11.62767833073934,
#  'COMBO_Season_Mulching_Used_TE_cls2': 11.610037231445313,
#  'Region_TE_cls1': 11.603482246398926,
#  'Electrical_Conductivity_digit-4_TE_cls2': 11.593777815500895,
#  'Organic_Carbon_digit-2_TE_cls1': 11.576345793406169,
#  'Electrical_Conductivity_digit-3_TE_cls0': 11.547637335459392,
#  'Temperature_C_digit-1_TE_cls0': 11.516357294718425,
#  'Previous_Irrigation_mm_digit-1_TE_cls0': 11.51484104792277,
#  'ORIG_Previous_Irrigation_mm_std': 11.457171281178793,
#  'COMBO_Irrigation_Type_Water_Source_Mulching_Used_TE_cls0': 11.435468864440917,
#  'Temperature_C_digit-1_TE_cls1': 11.433486366271973,
#  'Rainfall_mm_digit1_TE_cls2': 11.41967322031657,
#  'Irrigation_Type_TE_cls2': 11.4085618019104,
#  'Rainfall_mm_digit-1_TE_cls1': 11.325293731689452,
#  'COMBO_Season_Mulching_Used_Region_TE_cls1': 11.320611921946208,
#  'COMBO_Soil_Type_Crop_Type_Crop_Growth_Stage_TE_cls1': 11.315178298950196,
#  'COMBO_Crop_Type_Mulching_Used_Region_TE_cls1': 11.296041202545165,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Water_Source_TE_cls1': 11.287539990743001,
#  'Crop_Growth_Stage_TE_cls1': 11.276344712575277,
#  'COMBO_Soil_Type_Crop_Type_Region_TE_cls0': 11.271363894144693,
#  'COMBO_Soil_Type_Mulching_Used_Region_TE_cls2': 11.255958398183187,
#  'COMBO_Soil_Type_Season_Irrigation_Type_TE_cls2': 11.236435985565185,
#  'Humidity_digit-4_TE_cls1': 11.20861660639445,
#  'Field_Area_hectare_digit-2_TE_cls1': 11.181867822011311,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Season_TE_cls0': 11.162454907099406,
#  'COMBO_Irrigation_Type_Mulching_Used_Region_TE_cls0': 11.161731227238972,
#  'Sunlight_Hours_digit1_TE_cls2': 11.138261795043945,
#  'Rainfall_mm_digit3_TE_cls1': 11.127457237243652,
#  'Previous_Irrigation_mm_digit1_TE_cls1': 11.12387294769287,
#  'COMBO_Irrigation_Type_Water_Source_TE_cls1': 11.10950066248576,
#  'FREQ_COMBO_Crop_Growth_Stage_Season_Water_Source': 11.067311731974284,
#  'ORIG_Temperature_C_mean': 11.063084729512532,
#  'FREQ_COMBO_Season_Water_Source': 11.05769871075948,
#  'Temperature_C_digit0_TE_cls0': 11.01296189626058,
#  'Season_TE_cls0': 11.009345213572184,
#  'COMBO_Crop_Growth_Stage_Irrigation_Type_TE_cls1': 11.008599472045898,
#  'COMBO_Crop_Type_Irrigation_Type_TE_cls2': 10.974011452992757,
#  'COMBO_Season_Irrigation_Type_Mulching_Used_TE_cls1': 10.962232780456542,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Region_TE_cls2': 10.952618757883707,
#  'COMBO_Soil_Type_Season_Mulching_Used_TE_cls2': 10.95057430267334,
#  'COMBO_Water_Source_Region_TE_cls1': 10.930274105072021,
#  'COMBO_Irrigation_Type_Mulching_Used_Region_TE_cls1': 10.92003189722697,
#  'Organic_Carbon_digit-4_TE_cls2': 10.91895767847697,
#  'Sunlight_Hours': 10.908976236979166,
#  'Wind_Speed_kmh_digit-3_TE_cls1': 10.90050983428955,
#  'FREQ_COMBO_Soil_Type_Crop_Type_Irrigation_Type': 10.890820535024007,
#  'Previous_Irrigation_mm_digit2_TE_cls0': 10.854393132527669,
#  'Crop_Type_TE_cls1': 10.845224475860595,
#  'Soil_Moisture_digit-3_TE_cls1': 10.80608517328898,
#  'COMBO_Soil_Type_Irrigation_Type_Mulching_Used_TE_cls1': 10.797104406356812,
#  'Rainfall_mm_digit-4_TE_cls1': 10.782343991597493,
#  'FREQ_COMBO_Crop_Growth_Stage_Water_Source_Mulching_Used': 10.77641388575236,
#  'Electrical_Conductivity_digit-4_TE_cls1': 10.767033545176188,
#  'FREQ_COMBO_Soil_Type_Irrigation_Type_Region': 10.760380792617799,
#  'Soil_pH_digit-3_TE_cls1': 10.753142293294271,
#  'Field_Area_hectare': 10.747254848480225,
#  'FREQ_COMBO_Soil_Type_Water_Source_Mulching_Used': 10.735738404591878,
#  'Soil_Moisture_digit-1_TE_cls1': 10.734668890635172,
#  'Soil_pH_digit-4_TE_cls1': 10.72431402206421,
#  'Previous_Irrigation_mm_digit-4_TE_cls2': 10.712492879231771,
#  'COMBO_Crop_Type_Irrigation_Type_Water_Source_TE_cls1': 10.707719326019287,
#  'Rainfall_mm_digit-1_TE_cls2': 10.703662713368734,
#  'COMBO_Irrigation_Type_Water_Source_Region_TE_cls0': 10.703103478749593,
#  'Organic_Carbon_digit-3_TE_cls2': 10.69320395787557,
#  'Soil_Moisture_digit-4_TE_cls2': 10.686508655548096,
#  'Field_Area_hectare_digit1_TE_cls1': 10.681516679128011,
#  'Field_Area_hectare_digit1_TE_cls2': 10.670695972442626,
#  'Soil_pH_digit-3_TE_cls2': 10.66447509129842,
#  'Electrical_Conductivity_digit-4_TE_cls0': 10.661102294921875,
#  'COMBO_Irrigation_Type_Region_TE_cls2': 10.660688400268555,
#  'Season_TE_cls2': 10.648134009043376,
#  'COMBO_Soil_Type_Crop_Type_Crop_Growth_Stage_TE_cls0': 10.638291772206625,
#  'COMBO_Season_Mulching_Used_Region_TE_cls2': 10.626573816935222,
#  'COMBO_Soil_Type_Season_TE_cls0': 10.625805981953938,
#  'Soil_Moisture_digit-4_TE_cls0': 10.614229583740235,
#  'COMBO_Crop_Growth_Stage_Water_Source_TE_cls1': 10.604025586446125,
#  'COMBO_Crop_Growth_Stage_Irrigation_Type_TE_cls0': 10.600423781077067,
#  'COMBO_Crop_Type_Water_Source_Region_TE_cls2': 10.59630397160848,
#  'COMBO_Soil_Type_Water_Source_Region_TE_cls2': 10.589702288309732,
#  'Water_Source_TE_cls0': 10.585151036580404,
#  'COMBO_Season_Irrigation_Type_Mulching_Used_TE_cls0': 10.569435727596282,
#  'COMBO_Soil_Type_Irrigation_Type_Water_Source_TE_cls2': 10.559286530812582,
#  'FREQ_COMBO_Crop_Type_Irrigation_Type': 10.550838788350424,
#  'COMBO_Season_Region_TE_cls2': 10.547239112854005,
#  'COMBO_Soil_Type_Irrigation_Type_TE_cls1': 10.54723014831543,
#  'Previous_Irrigation_mm_digit-3_TE_cls1': 10.546962801615397,
#  'Water_Source_TE_cls2': 10.545257918039958,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Region_TE_cls0': 10.525476360321045,
#  'Soil_pH_digit-1_TE_cls2': 10.519516118367513,
#  'COMBO_Soil_Type_Crop_Type_Irrigation_Type_TE_cls2': 10.51250769297282,
#  'FREQ_COMBO_Irrigation_Type_Water_Source_Region': 10.511835734049479,
#  'COMBO_Irrigation_Type_Water_Source_Region_TE_cls1': 10.499143664042155,
#  'COMBO_Crop_Growth_Stage_Region_TE_cls1': 10.498573144276937,
#  'Rainfall_mm_digit-3_TE_cls0': 10.497159576416015,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Region_TE_cls0': 10.4938707669576,
#  'COMBO_Crop_Type_Season_TE_cls1': 10.490702692667643,
#  'Humidity_digit-1_TE_cls0': 10.461551316579182,
#  'COMBO_Soil_Type_Crop_Type_Mulching_Used_TE_cls1': 10.439172999064128,
#  'Wind_Speed_kmh_digit-2_TE_cls2': 10.434161440531414,
#  'ORIG_Electrical_Conductivity_mean': 10.394651063283284,
#  'Rainfall_mm_digit1_TE_cls0': 10.394328435262045,
#  'Organic_Carbon_digit-3_TE_cls1': 10.39335978825887,
#  'Previous_Irrigation_mm_digit-3_TE_cls0': 10.387500603993734,
#  'Electrical_Conductivity_digit-2_TE_cls0': 10.378449153900146,
#  'COMBO_Crop_Type_Region_TE_cls2': 10.376771545410156,
#  'Soil_Moisture_digit-3_TE_cls0': 10.36064001719157,
#  'FREQ_COMBO_Soil_Type_Crop_Type_Season': 10.354515520731608,
#  'COMBO_Irrigation_Type_Region_TE_cls0': 10.34079917271932,
#  'COMBO_Crop_Type_Season_Region_TE_cls1': 10.331974315643311,
#  'Rainfall_mm_digit-4_TE_cls0': 10.322294839223225,
#  'Humidity_digit-2_TE_cls2': 10.317934226989745,
#  'Wind_Speed_kmh_digit-4_TE_cls1': 10.31113697687785,
#  'COMBO_Soil_Type_Season_Irrigation_Type_TE_cls1': 10.311065260569254,
#  'Rainfall_mm_digit0_TE_cls1': 10.302818870544433,
#  'COMBO_Water_Source_Region_TE_cls2': 10.275368531545004,
#  'COMBO_Soil_Type_Crop_Type_Region_TE_cls2': 10.261392052968343,
#  'Field_Area_hectare_digit-1_TE_cls1': 10.24747018814087,
#  'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Mulching_Used': 10.246678765614828,
#  'COMBO_Soil_Type_Season_Water_Source_TE_cls0': 10.241422430674236,
#  'Wind_Speed_kmh_digit-3_TE_cls0': 10.220214549700419,
#  'COMBO_Season_Irrigation_Type_Water_Source_TE_cls2': 10.218294715881347,
#  'FREQ_COMBO_Soil_Type_Crop_Type_Water_Source': 10.216902128855388,
#  'Soil_Moisture_digit-1_TE_cls0': 10.206044991811117,
#  'Previous_Irrigation_mm_digit-2_TE_cls0': 10.192078781127929,
#  'Wind_Speed_kmh_digit-4_TE_cls0': 10.188617038726807,
#  'COMBO_Soil_Type_Water_Source_TE_cls1': 10.180142084757486,
#  'Previous_Irrigation_mm_digit2_TE_cls2': 10.170006593068441,
#  'COMBO_Soil_Type_Crop_Type_Water_Source_TE_cls0': 10.125397078196208,
#  'COMBO_Crop_Type_Region_TE_cls1': 10.113262144724528,
#  'COMBO_Crop_Type_Water_Source_TE_cls0': 10.101344362894695,
#  'COMBO_Crop_Type_Season_Mulching_Used_TE_cls1': 10.093216800689698,
#  'Temperature_C_digit-2_TE_cls1': 10.067844486236572,
#  'Soil_Moisture_digit-3_TE_cls2': 10.045633538564045,
#  'FREQ_COMBO_Crop_Type_Season_Irrigation_Type': 10.017671171824137,
#  'Humidity_digit-3_TE_cls2': 10.013963953653972,
#  'COMBO_Irrigation_Type_Water_Source_Region_TE_cls2': 9.999109776814779,
#  'COMBO_Soil_Type_Irrigation_Type_TE_cls0': 9.998376019795735,
#  'COMBO_Season_Irrigation_Type_Water_Source_TE_cls1': 9.994973786671956,
#  'Humidity_digit-1_TE_cls2': 9.982119146982829,
#  'ORIG_Previous_Irrigation_mm_mean': 9.97515157063802,
#  'Electrical_Conductivity_digit0_TE_cls1': 9.964096927642823,
#  'COMBO_Soil_Type_Crop_Type_Season_TE_cls1': 9.962589359283447,
#  'FREQ_COMBO_Crop_Growth_Stage_Season': 9.948143736521404,
#  'ORIG_Soil_pH_std': 9.94791849454244,
#  'Organic_Carbon_digit0_TE_cls2': 9.93915974299113,
#  'COMBO_Soil_Type_Season_Water_Source_TE_cls1': 9.91958646774292,
#  'COMBO_Soil_Type_Season_TE_cls1': 9.918911425272624,
#  'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Region': 9.91262350877126,
#  'Organic_Carbon_digit0_TE_cls0': 9.90441608428955,
#  'COMBO_Soil_Type_Water_Source_TE_cls0': 9.902706782023111,
#  'soil_lt_25_TE_cls2': 9.895652794837952,
#  'COMBO_Crop_Growth_Stage_Season_Water_Source_TE_cls2': 9.889496803283691,
#  'Temperature_C_digit-3_TE_cls2': 9.889462121327718,
#  'FREQ_COMBO_Crop_Type_Season_Water_Source': 9.888259506225586,
#  'COMBO_Crop_Growth_Stage_Season_TE_cls1': 9.888021596272786,
#  'Crop_Type_TE_cls2': 9.88043581644694,
#  'COMBO_Soil_Type_Season_Mulching_Used_TE_cls0': 9.875777530670167,
#  'Field_Area_hectare_digit-3_TE_cls2': 9.871014753977457,
#  'COMBO_Season_Irrigation_Type_TE_cls0': 9.86317590077718,
#  'COMBO_Crop_Type_Irrigation_Type_Mulching_Used_TE_cls1': 9.848471546173096,
#  'FREQ_COMBO_Crop_Growth_Stage_Water_Source_Region': 9.844433275858561,
#  'Wind_Speed_kmh_digit-2_TE_cls1': 9.839313983917236,
#  'COMBO_Soil_Type_Crop_Type_TE_cls2': 9.828426202138266,
#  'COMBO_Season_Irrigation_Type_Region_TE_cls0': 9.818093760808308,
#  'COMBO_Soil_Type_Region_TE_cls0': 9.815708764394124,
#  'COMBO_Season_Water_Source_TE_cls2': 9.807659419377645,
#  'FREQ_COMBO_Crop_Growth_Stage_Irrigation_Type_Water_Source': 9.806773948669434,
#  'ORIG_Field_Area_hectare_std': 9.801511796315511,
#  'Sunlight_Hours_digit-4_TE_cls1': 9.801340770721435,
#  'Temperature_C_digit-3_TE_cls0': 9.78851277033488,
#  'Field_Area_hectare_digit-4_TE_cls1': 9.78590342203776,
#  'COMBO_Crop_Type_Water_Source_TE_cls1': 9.781784598032633,
#  'Organic_Carbon_digit0_TE_cls1': 9.763114198048909,
#  'Soil_pH_digit-4_TE_cls0': 9.755107466379801,
#  'Season_TE_cls1': 9.75256280899048,
#  'FREQ_COMBO_Crop_Type_Water_Source_Region': 9.748456796010336,
#  'Soil_Moisture_digit-2_TE_cls1': 9.742105770111085,
#  'Humidity_digit-3_TE_cls0': 9.73080857594808,
#  'COMBO_Soil_Type_Season_Region_TE_cls1': 9.711107444763183,
#  'COMBO_Crop_Growth_Stage_Season_TE_cls2': 9.707810751597087,
#  'Temperature_C_digit-4_TE_cls1': 9.706174739201863,
#  'ORIG_Sunlight_Hours_std': 9.700488217671712,
#  'COMBO_Soil_Type_Crop_Growth_Stage_Season_TE_cls2': 9.682660961151123,
#  'Field_Area_hectare_digit-3_TE_cls1': 9.680368741353353,
#  'COMBO_Crop_Type_Season_Mulching_Used_TE_cls0': 9.677550029754638,
#  'COMBO_Crop_Type_Irrigation_Type_Water_Source_TE_cls0': 9.642975330352783,
#  'Soil_pH_digit-1_TE_cls1': 9.63689603805542,
#  'Field_Area_hectare_digit-1_TE_cls0': 9.6319122950236,
#  'COMBO_Season_Irrigation_Type_Region_TE_cls2': 9.629508304595948,
#  'COMBO_Soil_Type_Crop_Type_Irrigation_Type_TE_cls1': 9.625490347544352,
#  'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Water_Source': 9.62467492421468,
#  'Previous_Irrigation_mm_digit-2_TE_cls1': 9.619337526957194,
#  'Humidity_digit-4_TE_cls0': 9.617418034871418,
#  'COMBO_Soil_Type_Irrigation_Type_Region_TE_cls1': 9.617081928253175,
#  'ORIG_Wind_Speed_kmh_mean': 9.61441764831543,
#  'Rainfall_mm_digit3_TE_cls2': 9.610653305053711,
#  'COMBO_Crop_Growth_Stage_Season_Region_TE_cls1': 9.596977615356446,
#  'Previous_Irrigation_mm_digit-1_TE_cls2': 9.589192962646484,
#  'COMBO_Soil_Type_Season_Mulching_Used_TE_cls1': 9.569508043924968,
#  'Sunlight_Hours_digit-3_TE_cls2': 9.568276723225912,
#  'FREQ_COMBO_Crop_Type_Irrigation_Type_Region': 9.543760935465494,
#  'Electrical_Conductivity_digit-1_TE_cls0': 9.53611707687378,
#  'Organic_Carbon_digit-1_TE_cls0': 9.532646338144938,
#  'Crop_Growth_Stage_TE_cls2': 9.529360485076904,
#  'COMBO_Soil_Type_Crop_Type_Water_Source_TE_cls1': 9.527185344696045,
#  'Rainfall_mm_digit-3_TE_cls1': 9.5266445795695,
#  'Soil_pH_digit-1_TE_cls0': 9.519494851430258,
#  'Soil_Moisture_digit-4_TE_cls1': 9.508166694641114,
#  'Sunlight_Hours_digit-3_TE_cls0': 9.50425001780192,
#  'Electrical_Conductivity_digit-2_TE_cls2': 9.496058622996012,
#  'FREQ_COMBO_Soil_Type_Crop_Type_Crop_Growth_Stage': 9.495043627421062,
#  'FREQ_COMBO_Irrigation_Type_Mulching_Used_Region': 9.494155804316202,
#  'Soil_pH_digit-4_TE_cls2': 9.485043080647786,
#  'Electrical_Conductivity_digit-2_TE_cls1': 9.463644472757975,
#  'Region_TE_cls0': 9.457906595865886,
#  'COMBO_Soil_Type_Water_Source_Region_TE_cls0': 9.455594062805176,
#  'Soil_Type_TE_cls2': 9.455341370900472,
#  'Wind_Speed_kmh_digit-1_TE_cls2': 9.45477720896403,
#  'COMBO_Soil_Type_Irrigation_Type_Region_TE_cls0': 9.443909517923991,
#  'COMBO_Season_Water_Source_TE_cls1': 9.427518494923909,
#  'COMBO_Soil_Type_Region_TE_cls1': 9.41306765874227,
#  'Temperature_C_digit-2_TE_cls0': 9.412034765879314,
#  'COMBO_Crop_Type_Season_Region_TE_cls2': 9.410419877370199,
#  'Sunlight_Hours_digit-3_TE_cls1': 9.406572500864664,
#  'ORIG_Soil_pH_mean': 9.405297660827637,
#  'FREQ_COMBO_Water_Source_Region': 9.401347986857097,
#  'Sunlight_Hours_digit-4_TE_cls0': 9.399410823980967,
#  'Field_Area_hectare_digit-2_TE_cls0': 9.392709732055664,
#  'COMBO_Soil_Type_Region_TE_cls2': 9.385012340545654,
#  'Electrical_Conductivity_digit-1_TE_cls1': 9.372593212127686,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Region_TE_cls1': 9.36908942858378,
#  'Sunlight_Hours_digit-1_TE_cls0': 9.366399955749511,
#  'Field_Area_hectare_digit-3_TE_cls0': 9.365118471781413,
#  'Organic_Carbon_digit-2_TE_cls0': 9.351581350962322,
#  'FREQ_COMBO_Crop_Growth_Stage_Season_Region': 9.343699757258097,
#  'Wind_Speed_kmh_digit-2_TE_cls0': 9.335638395945232,
#  'Soil_pH_digit-3_TE_cls0': 9.334265518188477,
#  'COMBO_Crop_Type_Season_Water_Source_TE_cls1': 9.324665101369222,
#  'ORIG_Sunlight_Hours_mean': 9.309060509999593,
#  'COMBO_Season_Region_TE_cls0': 9.303686078389486,
#  'Region_TE_cls2': 9.291448783874511,
#  'COMBO_Crop_Type_Crop_Growth_Stage_Season_TE_cls0': 9.275373204549153,
#  'Organic_Carbon_digit-1_TE_cls1': 9.267312908172608,
#  'Organic_Carbon_digit-3_TE_cls0': 9.255562877655029,
#  'COMBO_Soil_Type_Crop_Type_Region_TE_cls1': 9.254597123463949,
#  'Field_Area_hectare_digit1_TE_cls0': 9.250115998586018,
#  'COMBO_Season_Water_Source_Region_TE_cls0': 9.236428101857504,
#  'COMBO_Season_Water_Source_Region_TE_cls1': 9.233991686503092,
#  'Electrical_Conductivity_digit-3_TE_cls2': 9.233745511372884,
#  'Temperature_C_digit-3_TE_cls1': 9.218109639485677,
#  'COMBO_Crop_Growth_Stage_Season_Irrigation_Type_TE_cls2': 9.212630065282186,
#  'Humidity_digit-2_TE_cls1': 9.212278493245442,
#  'FREQ_Crop_Type': 9.20260690053304,
#  'Temperature_C_digit-4_TE_cls0': 9.201057688395183,
#  'Wind_Speed_kmh_digit-1_TE_cls1': 9.199452527364095,
#  'Rainfall_mm_digit-3_TE_cls2': 9.196529420216878,
#  'Humidity_digit-3_TE_cls1': 9.183676179250082,
#  'Electrical_Conductivity_digit0_TE_cls0': 9.182712841033936,
#  'Soil_pH_digit-2_TE_cls2': 9.169454542795817,
#  'Humidity_digit-4_TE_cls2': 9.16373020807902,
#  'Soil_Moisture_digit-2_TE_cls2': 9.152914873758952,
#  'Sunlight_Hours_digit-1_TE_cls1': 9.13564036687215,
#  'COMBO_Season_Water_Source_Mulching_Used_TE_cls2': 9.135260423024496,
#  'FREQ_COMBO_Crop_Type_Mulching_Used_Region': 9.133354949951173,
#  'COMBO_Crop_Type_Crop_Growth_Stage_TE_cls1': 9.106173356374105,
#  'COMBO_Season_Region_TE_cls1': 9.104962984720865,
#  'Temperature_C_digit-4_TE_cls2': 9.075489902496338,
#  'Humidity_digit-2_TE_cls0': 9.07074982325236,
#  'Sunlight_Hours_digit-1_TE_cls2': 9.064413897196452,
#  'COMBO_Crop_Type_Irrigation_Type_TE_cls0': 9.061713790893554,
#  'COMBO_Crop_Type_Season_Water_Source_TE_cls0': 9.0612930615743,
#  'COMBO_Crop_Type_Region_TE_cls0': 9.055679225921631,
#  'COMBO_Crop_Type_Water_Source_Region_TE_cls1': 9.053843911488851,
#  'Electrical_Conductivity_digit-1_TE_cls2': 9.050759824117025,
#  'Sunlight_Hours_digit-4_TE_cls2': 9.041469192504882,
#  'Rainfall_mm_digit-4_TE_cls2': 9.038989607493082,
#  'COMBO_Soil_Type_Irrigation_Type_TE_cls2': 9.035910113652546,
#  'FREQ_COMBO_Crop_Type_Irrigation_Type_Water_Source': 9.031918780008953,
#  'FREQ_COMBO_Season_Mulching_Used_Region': 9.030876445770264,
#  'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Mulching_Used': 9.02066601117452,
#  'COMBO_Crop_Type_Irrigation_Type_Region_TE_cls2': 9.013175455729167,
#  'COMBO_Soil_Type_Crop_Type_TE_cls1': 9.001022116343181,
#  'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Season': 8.997931734720867,
#  'Field_Area_hectare_digit0_TE_cls0': 8.98627405166626,
#  'Rainfall_mm_digit-2_TE_cls0': 8.983991082509359,
#  'Organic_Carbon_digit-1_TE_cls2': 8.975639788309733,
#  'FREQ_COMBO_Soil_Type_Season_Region': 8.962644735972086,
#  'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Water_Source': 8.957150761286417,
#  'ORIG_Soil_Moisture_std': 8.953409238656361,
#  'Crop_Growth_Stage_TE_cls0': 8.943400001525879,
#  'Soil_pH_digit0_TE_cls0': 8.925400161743164,
#  'COMBO_Soil_Type_Crop_Type_Season_TE_cls0': 8.910441239674887,
#  'Sunlight_Hours_digit-2_TE_cls1': 8.89723596572876,
#  'Soil_pH_digit-2_TE_cls0': 8.896729469299316,
#  'FREQ_COMBO_Irrigation_Type_Water_Source': 8.883430480957031,
#  'FREQ_COMBO_Season_Irrigation_Type_Water_Source': 8.87012513478597,
#  'FREQ_COMBO_Season_Mulching_Used': 8.869867197672527,
#  'COMBO_Soil_Type_Irrigation_Type_Water_Source_TE_cls0': 8.865006446838379,
#  'COMBO_Crop_Type_Irrigation_Type_Region_TE_cls0': 8.864432366689046,
#  'FREQ_COMBO_Soil_Type_Season_Water_Source': 8.864345486958822,
#  'Organic_Carbon': 8.856715520222982,
#  'COMBO_Soil_Type_Crop_Type_TE_cls0': 8.853385512034098,
#  'Rainfall_mm_digit-2_TE_cls1': 8.840197658538818,
#  'COMBO_Crop_Type_Season_Region_TE_cls0': 8.83048407236735,
#  'FREQ_COMBO_Crop_Type_Mulching_Used': 8.830104915301005,
#  'Temperature_C_digit-2_TE_cls2': 8.822214476267497,
#  'COMBO_Season_Water_Source_Region_TE_cls2': 8.819442383448283,
#  'Crop_Type_TE_cls0': 8.818151744206746,
#  'Soil_pH_digit-2_TE_cls1': 8.817367394765219,
#  'Wind_Speed_kmh_digit-3_TE_cls2': 8.795865027109782,
#  'Field_Area_hectare_digit-2_TE_cls2': 8.793376318613689,
#  'COMBO_Soil_Type_Season_Region_TE_cls0': 8.790387630462646,
#  'Wind_Speed_kmh_digit-4_TE_cls2': 8.779165744781494,
#  'Soil_Moisture_digit-2_TE_cls0': 8.776726086934408,
#  'Field_Area_hectare_digit-4_TE_cls2': 8.774987475077312,
#  'COMBO_Soil_Type_Crop_Type_Season_TE_cls2': 8.706075795491536,
#  'COMBO_Crop_Growth_Stage_Season_Irrigation_Type_TE_cls0': 8.682011040051778,
#  'Sunlight_Hours_digit-2_TE_cls2': 8.665132808685303,
#  'FREQ_COMBO_Soil_Type_Water_Source_Region': 8.656513214111328,
#  'FREQ_COMBO_Crop_Type_Crop_Growth_Stage': 8.637962023417154,
#  'FREQ_COMBO_Crop_Growth_Stage_Mulching_Used_Region': 8.631691026687623,
#  'Previous_Irrigation_mm_digit-2_TE_cls2': 8.629757849375407,
#  'Previous_Irrigation_mm_digit-4_TE_cls0': 8.603993670145671,
#  'COMBO_Soil_Type_Season_Region_TE_cls2': 8.558419688542683,
#  'FREQ_COMBO_Crop_Growth_Stage_Irrigation_Type_Mulching_Used': 8.556250953674317,
#  'COMBO_Season_Irrigation_Type_TE_cls2': 8.548590342203775,
#  'Field_Area_hectare_digit0_TE_cls1': 8.539481099446615,
#  'FREQ_COMBO_Irrigation_Type_Region': 8.539400418599447,
#  'FREQ_COMBO_Soil_Type_Irrigation_Type_Water_Source': 8.534625084201496,
#  'Electrical_Conductivity_digit0_TE_cls2': 8.520316823323567,
#  'FREQ_COMBO_Soil_Type_Crop_Type_Region': 8.5174329439799,
#  'Rainfall_mm_digit-2_TE_cls2': 8.478726196289063,
#  'ORIG_Humidity_std': 8.471689701080322,
#  'FREQ_COMBO_Crop_Type_Season_Region': 8.455761591593424,
#  'COMBO_Soil_Type_Irrigation_Type_Region_TE_cls2': 8.445894002914429,
#  'Field_Area_hectare_digit-1_TE_cls2': 8.418189016977946,
#  'Sunlight_Hours_digit-2_TE_cls0': 8.408917999267578,
#  'COMBO_Season_Mulching_Used_TE_cls0': 8.405108896891276,
#  'COMBO_Soil_Type_Water_Source_Region_TE_cls1': 8.40283489227295,
#  'COMBO_Crop_Growth_Stage_Irrigation_Type_Region_TE_cls2': 8.39522819519043,
#  'Previous_Irrigation_mm_digit-4_TE_cls1': 8.365203094482421,
#  'COMBO_Crop_Growth_Stage_Season_Region_TE_cls2': 8.341174533963203,
#  'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Irrigation_Type': 8.32724733352661,
#  'FREQ_COMBO_Crop_Type_Season_Mulching_Used': 8.310429286956786,
#  'FREQ_COMBO_Crop_Type_Crop_Growth_Stage_Region': 8.251466528574626,
#  'FREQ_COMBO_Soil_Type_Irrigation_Type_Mulching_Used': 8.236917050679525,
#  'FREQ_COMBO_Season_Irrigation_Type_Mulching_Used': 8.201302623748779,
#  'FREQ_COMBO_Soil_Type_Crop_Type_Mulching_Used': 8.164282355705897,
#  'COMBO_Crop_Type_Season_TE_cls0': 8.158934768040975,
#  'COMBO_Season_Water_Source_TE_cls0': 8.14538516998291,
#  'COMBO_Crop_Type_Season_Irrigation_Type_TE_cls2': 8.108342806498209,
#  'FREQ_COMBO_Season_Water_Source_Mulching_Used': 8.066018056869506,
#  'FREQ_COMBO_Crop_Growth_Stage_Irrigation_Type': 8.065228811899821,
#  'FREQ_COMBO_Crop_Growth_Stage_Water_Source': 8.05332145690918,
#  'Field_Area_hectare_digit-4_TE_cls0': 8.033475653330486,
#  'COMBO_Crop_Type_Irrigation_Type_Mulching_Used_TE_cls0': 7.996177228291829,
#  'FREQ_COMBO_Season_Irrigation_Type_Region': 7.926479212443033,
#  'FREQ_COMBO_Irrigation_Type_Water_Source_Mulching_Used': 7.9025858243306475,
#  'COMBO_Soil_Type_Crop_Type_Irrigation_Type_TE_cls0': 7.901080735524496,
#  'FREQ_COMBO_Soil_Type_Season_Irrigation_Type': 7.805795383453369,
#  'COMBO_Soil_Type_Season_Irrigation_Type_TE_cls0': 7.792118072509766,
#  'ORIG_Wind_Speed_kmh_std': 7.755420303344726,
#  'COMBO_Soil_Type_Season_TE_cls2': 7.701583925882975,
#  'COMBO_Soil_Type_Crop_Growth_Stage_TE_cls1': 7.687848409016927,
#  'FREQ_COMBO_Crop_Growth_Stage_Irrigation_Type_Region': 7.671258131663005,
#  'COMBO_Crop_Growth_Stage_Region_TE_cls2': 7.587648073832194,
#  'FREQ_COMBO_Crop_Type_Irrigation_Type_Mulching_Used': 7.584421062469483,
#  'FREQ_COMBO_Soil_Type_Crop_Growth_Stage_Season': 7.535250933965047,
#  'FREQ_COMBO_Soil_Type_Season_Mulching_Used': 7.518449703852336,
#  'FREQ_Season': 7.372688436508179,
#  'FREQ_COMBO_Crop_Growth_Stage_Season_Irrigation_Type': 6.986677805582683,
#  'FREQ_COMBO_Crop_Type_Region': 6.5772362867991125,
#  'FREQ_COMBO_Crop_Type_Season': 6.561219580968221,
#  'FREQ_COMBO_Mulching_Used_Region': 5.469971593221029,
#  'FREQ_COMBO_Water_Source_Mulching_Used': 5.044093036651612,
#  'FREQ_Irrigation_Type': 2.4053054253260293,
#  'ORIG_Season_mean': 0.9668325424194336,
#  'FREQ_Water_Source': 0.5831643243630728}

# %%
def accuracy_score(t, p):
    if len(p.shape) == 2:
        p = np.argmax(p, axis=1)
    C = 3
    acc = 0.0
    for i in range(C):
        acc += np.sum((t == i) & (p == i)) / np.sum(t == i) / C
    return acc

# %% [markdown]
# # Post-processing: Optuna Class Weight Optimisation

# %%
oof_preds = oof
y = train[TARGET]

import optuna
from optuna.samplers import TPESampler

def objective(trial):
    cw1 = trial.suggest_float('cw1', 0.5, 3.0)
    cw2 = trial.suggest_float('cw2', 0.5, 3.0)
    cw3 = trial.suggest_float('cw3', 0.5, 3.0)

    class_weights   = np.array([cw1, cw2, cw3])
    adjusted_probs  = oof_preds * class_weights
    adjusted_probs /= adjusted_probs.sum(axis=1, keepdims=True)
    return accuracy_score(y, np.argmax(adjusted_probs, axis=1))

study = optuna.create_study(
    direction='maximize',
    sampler=TPESampler(seed=42),
    study_name='class_weight_optimization'
)
# Out:
# [I 2026-04-28 09:39:34,963] A new study created in memory with name: class_weight_optimization

# %%
# 500 trials (was 200) for better search coverage
study.optimize(objective, n_trials=500, show_progress_bar=True)

print(f"Best oof acc: {study.best_value:.6f}")
print(f"  class_0 (Low)    = {study.best_params['cw1']:.4f}")
print(f"  class_1 (Medium) = {study.best_params['cw2']:.4f}")
print(f"  class_2 (High)   = {study.best_params['cw3']:.4f}")

best_cw = np.array([study.best_params['cw1'],
                    study.best_params['cw2'],
                    study.best_params['cw3']])

final_oof_probs   = oof * best_cw
final_oof_probs  /= final_oof_probs.sum(axis=1, keepdims=True)

final_test_probs  = pred * best_cw
final_test_probs /= final_test_probs.sum(axis=1, keepdims=True)

final_test_preds  = np.argmax(final_test_probs, axis=1)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# [I 2026-04-28 09:39:35,047] Trial 0 finished with value: 0.9705083816001263 and parameters: {'cw1': 1.4363502971184063, 'cw2': 2.87678576602479, 'cw3': 2.3299848545285125}. Best is trial 0 with value: 0.9705083816001263.
# [I 2026-04-28 09:39:35,103] Trial 1 finished with value: 0.9716182606994437 and parameters: {'cw1': 1.9966462104925915, 'cw2': 0.8900466011060912, 'cw3': 0.8899863008405067}. Best is trial 1 with value: 0.9716182606994437.
. Best is trial 364 with value: 0.978449321125988.
# [I 2026-04-28 09:40:06,940] Trial 489 finished with value: 0.9781262843354857 and parameters: {'cw1': 0.5007316646318603, 'cw2': 0.5847057713638136, 'cw3': 2.789843473835929}. Best is trial 364 with value: 0.978449321125988.
# [I 2026-04-28 09:40:07,007] Trial 490 finished with value: 0.9783670098534711 and parameters: {'cw1': 0.6340015175123983, 'cw2': 0.5005399417245713, 'cw3': 2.9212692884311675}. Best is trial 364 with value: 0.978449321125988.
# [I 2026-04-28 09:40:07,077] Trial 491 finished with value: 0.9780054226757022 and parameters: {'cw1': 0.5469413465910845, 'cw2': 0.646858371997481, 'cw3': 2.8419090832724394}. Best is trial 364 with value: 0.978449321125988.
# [I 2026-04-28 09:40:07,146] Trial 492 finished with value: 0.9782840029935469 and parameters: {'cw1': 0.5833444199061371, 'cw2': 0.5530229011999533, 'cw3': 2.8851370636130387}. Best is trial 364 with value: 0.978449321125988.
# [I 2026-04-28 09:40:07,212] Trial 493 finished with value: 0.9783876041688228 and parameters: {'cw1': 0.5441782077998861, 'cw2': 0.5008921485416169, 'cw3': 2.8009614565141763}. Best is trial 364 with value: 0.978449321125988.
# [I 2026-04-28 09:40:07,281] Trial 494 finished with value: 0.9780830253069354 and parameters: {'cw1': 0.6542231328152638, 'cw2': 0.6083486931016093, 'cw3': 2.934269795402709}. Best is trial 364 with value: 0.978449321125988.
# [I 2026-04-28 09:40:07,348] Trial 495 finished with value: 0.9765006577972961 and parameters: {'cw1': 1.0303250226064153, 'cw2': 0.5459829870155292, 'cw3': 1.5256988224901915}. Best is trial 364 with value: 0.978449321125988.
# [I 2026-04-28 09:40:07,417] Trial 496 finished with value: 0.9774527391400964 and parameters: {'cw1': 0.5843280323441408, 'cw2': 0.5481502337965651, 'cw3': 1.9552771773464344}. Best is trial 364 with value: 0.978449321125988.
# [I 2026-04-28 09:40:07,482] Trial 497 finished with value: 0.9783682284973585 and parameters: {'cw1': 0.7333643849552872, 'cw2': 0.5002159107280074, 'cw3': 2.846633747436172}. Best is trial 364 with value: 0.978449321125988.
# [I 2026-04-28 09:40:07,554] Trial 498 finished with value: 0.9780787475448487 and parameters: {'cw1': 0.5451289539741372, 'cw2': 0.5858223335038498, 'cw3': 2.740635511438207}. Best is trial 364 with value: 0.978449321125988.
# [I 2026-04-28 09:40:07,623] Trial 499 finished with value: 0.9780359625282276 and parameters: {'cw1': 0.5008281684558104, 'cw2': 0.6537406452902118, 'cw3': 2.8897218407950436}. Best is trial 364 with value: 0.978449321125988.
# Best oof acc: 0.978449
#   class_0 (Low)    = 0.5013
#   class_1 (Medium) = 0.5009
#   class_2 (High)   = 2.8556

# %%
print(f'Overall Balanced Accuracy (after class-weight tuning): {metric(true, final_oof_probs)}')
# Out:
# Overall Balanced Accuracy (after class-weight tuning): 0.978449321125988

# %% [markdown]
# # Save CSV

# %%
# SAVE OOF TO DISK FOR ENSEMBLES
df_oof  = pd.DataFrame({'xgb': final_oof_probs.flatten()})
df_oof.to_csv(f'{NAME}_oof.csv', index=False)

df_test = pd.DataFrame({'xgb': final_test_probs.flatten()})
df_test.to_csv(f'{NAME}_test.csv', index=False)

print("Saved oof and test predictions to file")
# Out:
# Saved oof and test predictions to file

# %%
sub = pd.DataFrame({
    'id': test_ids,
    TARGET: final_test_preds
})
sub[TARGET] = sub[TARGET].map({0: 'Low', 1: 'Medium', 2: 'High'})

sub.to_csv(f'{NAME}_submission.csv', index=False)
print(f"Submission saved: {NAME}_submission.csv")
sub.head(10)
# Out:
# Submission saved: 002_submission.csv
#        id Irrigation_Need
# 0  630000             Low
# 1  630001             Low
# 2  630002             Low
# 3  630003             Low
# 4  630004             Low
# 5  630005          Medium
# 6  630006             Low
# 7  630007          Medium
# 8  630008          Medium
# 9  630009             Low
